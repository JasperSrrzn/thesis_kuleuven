# %%
# %load_ext gvmagic

# %%
from problog.engine import DefaultEngine
from problog.formula import LogicFormula
from problog.logic import *
from problog.program import PrologString
from data_processing import clear_data_part
from classifiers import SimpleClassifier
import pandas as pd
import problog
import numpy as np
import json
from scipy.stats import friedmanchisquare
# Out:
# /home/jasper/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
embeddings_enta = pd.read_csv('entity_embeddingsa.csv')
embeddings_entb = pd.read_csv('entity_embeddingsb.csv')
embeddings_rel = pd.read_csv('relation_embeddings.csv')
embeddings_rule = pd.read_csv('rule_embeddings.csv')

# %%
embeddings_rule = embeddings_rule.drop(['Unnamed: 0'],axis=1)

# %%
with open('dict_neighbors.json') as json_file:
    neighbors = json.load(json_file)

# %%
model = SimpleClassifier()

# %%
print('opening facts and rules')
with open('rules_and_facts.txt', 'r') as myfile:
    facts_and_rules = myfile.readlines()

facts_and_rules_Prolog = PrologString("\n".join(facts_and_rules))
# Out:
# opening facts and rules

# %%
test_data = pd.read_csv('test_data.csv')
test_data = test_data[['entity a','entity b','rel id']]
test_data = test_data.drop_duplicates()

# %%
row = test_data.iloc[0]
print(row)
rel_id = row['rel id']
ent_a = row['entity a']
ent_b = row['entity b']
query = Term('q'+str(rel_id),Term('ent'+str(ent_a)),Term('ent'+str(ent_b)))
# Out:
# entity a    2600
# entity b    3465
# rel id        69
# Name: 0, dtype: int64

# %%
def get_embedding_action(action,predicates,embeddings_enta,embeddings_entb,embeddings_rel,embeddings_rule,randenta,randentb):
    """
    function that concatenates the embeddings given the action = relation, entity a, entity b and rule
    """
    node = action[1]
    functor = db.get_node(node).functor
    for pred in predicates:
        if pred.functor == functor:
            enta = term2str(pred.args[0])
            entb = term2str(pred.args[1])
            if enta.find('ent')==-1:
                enta = randenta
                enta_emb = embeddings_enta[embeddings_enta['entity a']==enta]
                enta_emb = enta_emb.drop(['entity a'],axis=1)
                enta_emb = enta_emb.values.tolist()[0]
            else:
                enta = int(enta[enta.find('ent')+3:])
                enta_emb = embeddings_enta[embeddings_enta['entity a']==enta]
                enta_emb = enta_emb.drop(['entity a'],axis=1)
                enta_emb = enta_emb.values.tolist()[0]

            if entb.find('ent')==-1:
                entb = randentb
                entb_emb = embeddings_entb[embeddings_entb['entity b']==entb]
                entb_emb = entb_emb.drop(['entity b'],axis=1)
                entb_emb = entb_emb.values.tolist()[0]
            else:
                entb = int(entb[entb.find('ent')+3:])
                entb_emb = embeddings_entb[embeddings_entb['entity b']==entb]
                entb_emb = entb_emb.drop(['entity b'],axis=1)
                entb_emb = entb_emb.values.tolist()[0]


    rule_id = db.get_node(node).args[-1]
    rel_id = int(functor[functor.find('rel')+3:])
    rule_emb = embeddings_rule[(embeddings_rule['rule id']==rule_id) & (embeddings_rule['rel id']==rel_id)]
    rule_emb = rule_emb.drop(['rel id','rule id'],axis=1)
    rule_emb = rule_emb.values.tolist()[0]
    rel_emb = embeddings_rel[embeddings_rel['rel id']==rel_id]
    rel_emb = rel_emb.drop(['rel id'],axis=1)
    rel_emb = rel_emb.values.tolist()[0]


    features = enta_emb + entb_emb + rel_emb + rule_emb
    return [rel_id] + [enta] + [entb] + [rule_id] + features

# %%
def rerank_actions(actions,predicates,embeddings_enta,embeddings_entb,embeddings_rel,embeddings_rule,model,neighbors,rand_dict):
    actions_to_rerank = []
    reranked_actions = []
    pos = 0
    for act in actions:
        node = act[1]
        if (db.get_node(node).functor,db.get_node(node).args[:-1]) in rand_dict.keys():
            randenta = rand_dict[(db.get_node(node).functor,db.get_node(node).args[:-1])][0]
            randentb = rand_dict[(db.get_node(node).functor,db.get_node(node).args[:-1])][-1]
        else:
            used_preds = []
            pred_pos = 0
            for pred in predicates:
                if pred.functor == db.get_node(node).functor and pred_pos not in used_preds:
                    used_preds.append(pred_pos)
                    pred_pos+=1
                    enta = term2str(pred.args[0])
                    entb = term2str(pred.args[1])
                    if enta.find('ent')==-1:
                        entb = int(entb[entb.find('ent')+3:])
                        randentb = entb
                        randenta = neighbors[str(entb)][np.random.permutation(len(neighbors[str(entb)]))[0]]
                        rand_dict[(db.get_node(node).functor,db.get_node(node).args[:-1])]=[randenta,randentb]
                    elif entb.find('ent')==-1:
                        enta = int(enta[enta.find('ent')+3:])
                        randenta = enta
                        randentb = neighbors[str(enta)][np.random.permutation(len(neighbors[str(enta)]))[0]]
                        rand_dict[(db.get_node(node).functor,db.get_node(node).args[:-1])]=[randenta,randentb]
                    else:
                        randenta = np.random.permutation(14000)[0]
                        randentb = np.random.permutation(14000)[0]
                        rand_dict[(db.get_node(node).functor,db.get_node(node).args[:-1])]=[randenta,randentb]

        db_term = term2str(db.get_node(node))
        if db_term[:db_term.find('(')]=='clause':
            data = get_embedding_action(act,predicates,embeddings_enta,embeddings_entb,embeddings_rel,embeddings_rule,randenta,randentb)
            actions_to_rerank.append([pos] + data)
        pos+=1
    Reranked_Meta = pd.DataFrame([])
    if len(actions_to_rerank)>1:
        actions_to_rerank = pd.DataFrame(actions_to_rerank)
        Meta = actions_to_rerank[[0,1,2,3,4]]
        Data = actions_to_rerank.drop([0,1,2,3,4],axis=1)
        predictions = model.predict_proba('./classification_models/model_transe_50/',Data)
        heuristic = predictions[:,-1]
        Meta['heuristic'] = heuristic
        Meta = Meta.rename(columns={0:'position',1:'rel id',2:'ent a',3:'ent b',4:'rule id'})
        uniques = []
        for meta_i in range(1,len(Meta)):
            row = Meta.iloc[meta_i]
            if [row['rel id'],row['ent a'], row['ent b']] not in uniques:
                uniques.append([row['rel id'],row['ent a'], row['ent b']])
        for unique in uniques:
            rel_id = unique[0]
            enta = unique[1]
            entb = unique[2]
            Selected = Meta[(Meta['rel id']==rel_id) & (Meta['ent a']== enta) & (Meta['ent b']==entb)]
            Selected = Selected.sort_values(by=['heuristic'])
            #print(Selected)
            Reranked_Meta = Reranked_Meta.append(Selected)
        act_counter = 0
        for act_i in range(0,len(actions)):
            if act_i not in Reranked_Meta['position']:
                reranked_actions.append(actions[act_i])
            else:
                reranked_actions.append(actions[Reranked_Meta.iloc[act_counter]['position']])
                act_counter+=1

        return reranked_actions, rand_dict
    else:
        return actions,rand_dict

# %%
#no_rerank_results = pd.read_csv('results_no_rerank.csv')
#pd_results = pd.read_csv('pd_results.csv')
#results = list(pd_results['0'])
#no_rerank_results = list(no_rerank_results['no rerank'])
results = []
for test_sample in range(0,len(test_data)):
    try:
        print(test_sample)
        row = test_data.iloc[test_sample]
        rel_id = row['rel id']
        ent_a = row['entity a']
        ent_b = row['entity b']
        query = Term('q'+str(rel_id),Term('ent'+str(ent_a)),Term('ent'+str(ent_b)))
        # Perform incremental grounding.
        # This is a split-up of the engine.execute method.

        # Initialize the engine with options:
        #   - unbuffered: don't buffer results internally in the nodes (mimic depth-first construction of target)
        #   - rc_first: first process 'result' and 'complete' messages (allows stopping on 'evaluation' message)
        #   - label_all: (optional) label all intermediate nodes with their predicate
        engine = problog.engine.DefaultEngine(unbuffered=True, rc_first=True, label_all=True)

        # Target formula
        #   - keep_all: don't collapse non-probabilistic subformula's => only for visualization
        target = problog.formula.LogicFormula(keep_all=True)

        db = engine.prepare(facts_and_rules_Prolog)

        # Start the incremental grounding.
        # The result is a list of 'evaluation' actions.
        actions = list(reversed(engine.ground_step(db, query, gp=target)))

        i = 0
        # Execute until no more 'evaluation' actions can be performed.
        rand_dict={}
        while actions:
            actions = engine.execute_step(actions, steps=1, target=target, name=(False, query, 'query'))

            # HERE YOU CAN DO WHATEVER YOU WANT WITH THE ACTION LIST

            # Below is just generating some output.
            i += 1

            #print('==== STEP %d ====' % i)


            predicates = []
            # Go through the engine's stack and extract predicate evaluation nodes ('EvalDefine')
            for rec in engine.stack:
                if type(rec).__name__ == 'EvalDefine':  # TODO: we should also include 'EvalOr'?
                    nodes = set(b for a, b, in rec.results.results)  # 'target' nodes associated with this evaluation node
                    predicates.append(problog.logic.Term(rec.call[0], *rec.call[1]))
            #print(predicates)
            #actions,rand_dict = rerank_actions(actions,predicates,embeddings_enta,embeddings_entb,embeddings_rel,embeddings_rule,model,neighbors,rand_dict)

            #for act in actions:
            #    print(db.get_node(act[1]))

            if type(engine.stack[0]).__name__=='EvalDefine':
                trigger_nodes = set(b for a,b, in engine.stack[0].results.results)

            #print ('Active predicates:')
            active_nodes = set()  # These are the nodes in 'target' that are still active.
            # Go through the engine's stack and extract predicate evaluation nodes ('EvalDefine')
            for rec in engine.stack:
                if type(rec).__name__ == 'EvalDefine':  # TODO: we should also include 'EvalOr'?
                    nodes = set(b for a, b, in rec.results.results)  # 'target' nodes associated with this evaluation node
                    #print ('\t', problog.logic.Term(rec.call[0], *rec.call[1]), list(nodes))
                    active_nodes |= nodes # union
            #print ('Active nodes:', list(active_nodes))

            # Visualize and print the current logic program.
            #%dotstr target.to_dot(nodeprops={n: 'fillcolor="red"' for n in active_nodes})

            if len(list(trigger_nodes))>0:
                print(str(test_sample)+ ':solution found ('+str(i)+')')
                results.append(i)
                pd_results = pd.DataFrame(results)
                pd_results.to_csv('pd_results.csv',index=False)
                break

            if i>1000:
                print(str(test_sample)+ ':too long')
                results.append(0)
                pd_results = pd.DataFrame(results)
                pd_results.to_csv('pd_results.csv',index=False)
                break

            if len(actions)==0:
                print(str(test_sample)+ ':solution not found')
                results.append(-1)
                pd_results = pd.DataFrame(results)
                pd_results.to_csv('pd_results.csv',index=False)
                break

    except:
        print('cycle')
        results.append(-2)
        pass
# Out:
# 0
# 0:solution found (8)
# 1
# 1:solution found (8)
# 2
# 2:too long
# 3
# 3:solution found (10)
# 4
# 4:too long
# 5
# 5:solution found (7)
# 6
# 6:solution found (7)
# 7
# 7:solution found (7)
# 8
# 8:solution found (7)
# 9
# 9:solution found (9)
# 10
# 10:solution found (9)
# 11
# 11:too long
# 12
# 12:too long
# 13
# 13:too long
# 14
# 14:solution found (11)
# 15
# 15:too long
# 16
# 16:solution found (10)
# 17
# 17:too long
# 18
# 18:solution found (7)
# 19
# 19:solution found (9)
# 20
# 20:solution found (7)
# 21
# 21:too long
# 22
# 22:solution found (8)
# 23
# 23:too long
# 24
# 24:solution found (8)
# 25
# 25:solution found (9)
# 26
# 26:solution found (56)
# 27
# 27:solution found (9)
# 28
# 28:solution not found
# 29
# 29:solution found (9)
# 30
# 30:solution found (34)
# 31
# 31:too long
# 32
# 32:solution found (8)
# 33
# 33:solution found (10)
# 34
# 34:too long
# 35
# 35:too long
# 36
# 36:solution found (7)
# 37
# 37:solution found (9)
# 38
# 38:solution found (8)
# 39
# 39:solution found (9)
# 40
# 40:solution found (11)
# 41
# 41:solution found (8)
# 42
# 42:solution found (8)
# 43
# 43:too long
# 44
# 44:solution found (9)
# 45
# 45:solution found (7)
# 46
# 46:solution found (9)
# 47
# 47:solution found (7)
# 48
# 48:solution found (8)
# 49
# 49:solution found (8)
# 50
# 50:solution found (8)
# 51
# 51:too long
# 52
# 52:too long
# 53
# 53:solution found (9)
# 54
# 54:solution found (9)
# 55
# 55:solution found (10)
# 56
# 56:solution found (8)
# 57
# 57:solution found (9)
# 58
# 58:solution found (7)
# 59
# 59:too long
# 60
# 60:solution found (8)
# 61
# 61:solution found (8)
# 62
# 62:solution found (8)
# 63
# 63:solution found (9)
# 64
# 64:solution found (8)
# 65
# 65:solution found (9)
# 66
# 66:solution found (30)
# 67
# 67:solution found (12)
# 68
# 68:too long
# 69
# 69:too long
# 70
# 70:solution found (10)
# 71
# 71:too long
# 72
# 72:too long
# 73
# 73:solution found (7)
# 74
# 74:solution found (9)
# 75
# 75:solution found (7)
# 76
# 76:solution found (12)
# 77
# 77:solution not found
# 78
# 78:solution found (9)
# 79
# 79:too long
# 80
# 80:solution found (12)
# 81
# 81:too long
# 82
# 82:solution found (10)
# 83
# 83:too long
# 84
# 84:solution found (10)
# 85
# 85:solution found (10)
# 86
# 86:too long
# 87
# 87:solution found (9)
# 88
# 88:too long
# 89
# 89:solution found (8)
# 90
# 90:solution found (10)
# 91
# 91:solution found (8)
# 92
# 92:solution found (14)
# 93
# 93:solution found (7)
# 94
# 94:solution found (8)
# 95
# 95:too long
# 96
# 96:solution found (7)
# 97
# 97:too long
# 98
# 98:solution found (9)
# 99
# 99:solution found (7)
# 100
# 100:solution found (9)
# 101
# 101:solution found (11)
# 102
# 102:too long
# 103
# 103:solution found (54)
# 104
# 104:too long
# 105
# 105:solution found (8)
# 106
# 106:solution found (7)
# 107
# 107:solution found (7)
# 108
# 108:solution found (7)
# 109
# 109:too long
# 110
# 110:solution found (11)
# 111
# 111:too long
# 112
# 112:solution found (9)
# 113
# cycle
# 114
# 114:solution found (7)
# 115
# 115:too long
# 116
# 116:solution found (8)
# 117
# 117:solution found (7)
# 118
# 118:solution found (7)
# 119
# 119:too long
# 120
# 120:solution found (78)
# 121
# 121:too long
# 122
# 122:solution found (12)
# 123
# 123:solution found (8)
# 124
# 124:too long
# 125
# 125:too long
# 126
# 126:solution found (9)
# 127
# 127:too long
# 128
# 128:solution found (11)
# 129
# 129:solution found (9)
# 130
# 130:too long
# 131
# 131:solution found (8)
# 132
# 132:too long
# 133
# 133:solution found (9)
# 134
# 134:solution found (9)
# 135
# 135:solution found (7)
# 136
# 136:too long
# 137
# 137:too long
# 138
# 138:solution found (32)
# 139
# 139:solution found (7)
# 140
# 140:solution found (8)
# 141
# 141:solution found (8)
# 142
# 142:too long
# 143
# 143:solution found (9)
# 144
# 144:solution found (7)
# 145
# 145:solution found (9)
# 146
# 146:too long
# 147
# 147:solution found (9)
# 148
# 148:solution found (14)
# 149
# 149:solution found (10)
# 150
# 150:solution found (9)
# 151
# 151:solution found (10)
# 152
# 152:solution found (14)
# 153
# 153:solution found (9)
# 154
# 154:solution found (7)
# 155
# 155:solution found (9)
# 156
# 156:solution found (8)
# 157
# 157:solution found (33)
# 158
# 158:solution found (7)
# 159
# 159:solution found (7)
# 160
# cycle
# 161
# 161:solution found (8)
# 162
# 162:solution found (32)
# 163
# 163:solution found (7)
# 164
# 164:solution found (9)
# 165
# 165:solution found (33)
# 166
# 166:solution found (8)
# 167
# 167:solution found (7)
# 168
# 168:solution found (9)
# 169
# 169:too long
# 170
# 170:solution found (33)
# 171
# 171:solution found (7)
# 172
# 172:too long
# 173
# 173:solution found (7)
# 174
# 174:too long
# 175
# 175:solution found (7)
# 176
# 176:too long
# 177
# 177:solution found (7)
# 178
# 178:solution found (8)
# 179
# 179:solution found (8)
# 180
# 180:solution found (9)
# 181
# 181:too long
# 182
# 182:solution found (29)
# 183
# 183:solution found (11)
# 184
# 184:solution found (10)
# 185
# 185:solution found (9)
# 186
# 186:too long
# 187
# 187:too long
# 188
# 188:solution found (9)
# 189
# 189:solution found (12)
# 190
# 190:too long
# 191
# 191:solution found (10)
# 192
# 192:too long
# 193
# 193:solution found (8)
# 194
# 194:solution found (10)
# 195
# 195:solution found (8)
# 196
# 196:solution found (8)
# 197
# 197:solution found (7)
# 198
# 198:too long
# 199
# 199:solution found (10)
# 200
# 200:too long
# 201
# 201:solution found (7)
# 202
# 202:solution found (9)
# 203
# 203:solution found (29)
# 204
# 204:too long
# 205
# 205:solution found (8)
# 206
# 206:solution found (7)
# 207
# 207:solution found (8)
# 208
# 208:too long
# 209
# 209:solution found (7)
# 210
# 210:solution found (9)
# 211
# 211:solution found (7)
# 212
# 212:solution found (8)
# 213
# 213:too long
# 214
# 214:solution found (7)
# 215
# 215:solution found (7)
# 216
# 216:solution found (10)
# 217
# 217:too long
# 218
# 218:solution found (7)
# 219
# 219:solution found (7)
# 220
# 220:solution found (7)
# 221
# 221:solution found (8)
# 222
# 222:too long
# 223
# 223:too long
# 224
# 224:too long
# 225
# 225:solution found (9)
# 226
# 226:solution found (9)
# 227
# 227:too long
# 228
# 228:solution found (8)
# 229
# 229:solution found (9)
# 230
# 230:too long
# 231
# 231:solution found (7)
# 232
# 232:solution found (9)
# 233
# 233:solution found (8)
# 234
# 234:solution found (8)
# 235
# 235:solution not found
# 236
# 236:solution found (12)
# 237
# 237:solution found (7)
# 238
# 238:too long
# 239
# 239:solution found (7)
# 240
# 240:solution found (10)
# 241
# 241:solution found (9)
# 242
# 242:too long
# 243
# 243:solution found (8)
# 244
# 244:solution found (97)
# 245
# 245:too long
# 246
# 246:solution found (8)
# 247
# 247:solution found (8)
# 248
# 248:too long
# 249
# 249:solution found (33)
# 250
# 250:solution found (12)
# 251
# 251:solution found (11)
# 252
# 252:solution found (9)
# 253
# 253:solution found (9)
# 254
# 254:too long
# 255
# 255:solution found (8)
# 256
# 256:solution found (7)
# 257
# 257:too long
# 258
# 258:solution found (8)
# 259
# 259:solution found (7)
# 260
# 260:too long
# 261
# 261:solution not found
# 262
# 262:solution found (8)
# 263
# 263:solution found (7)
# 264
# 264:solution found (8)
# 265
# 265:solution found (8)
# 266
# 266:solution found (8)
# 267
# 267:solution found (9)
# 268
# 268:solution found (12)
# 269
# 269:too long
# 270
# 270:solution found (8)
# 271
# 271:solution found (7)
# 272
# 272:solution found (9)
# 273
# 273:solution found (9)
# 274
# 274:solution found (11)
# 275
# 275:too long
# 276
# 276:solution found (9)
# 277
# 277:solution found (9)
# 278
# 278:solution found (7)
# 279
# 279:solution found (9)
# 280
# 280:too long
# 281
# 281:solution found (8)
# 282
# 282:solution found (9)
# 283
# 283:solution found (8)
# 284
# 284:solution found (8)
# 285
# 285:too long
# 286
# 286:too long
# 287
# 287:solution found (9)
# 288
# 288:solution found (7)
# 289
# 289:too long
# 290
# 290:solution found (8)
# 291
# 291:solution found (7)
# 292
# 292:solution found (8)
# 293
# 293:solution found (9)
# 294
# 294:solution found (10)
# 295
# 295:solution found (10)
# 296
# 296:solution found (8)
# 297
# 297:solution found (9)
# 298
# 298:solution found (7)
# 299
# 299:solution found (7)
# 300
# 300:solution found (7)
# 301
# 301:solution found (10)
# 302
# 302:solution found (8)
# 303
# 303:solution not found
# 304
# 304:too long
# 305
# 305:solution found (8)
# 306
# 306:solution found (7)
# 307
# 307:solution found (12)
# 308
# 308:too long
# 309
# 309:solution not found
# 310
# 310:solution found (7)
# 311
# 311:solution found (9)
# 312
# 312:too long
# 313
# 313:solution found (8)
# 314
# 314:solution found (9)
# 315
# 315:too long
# 316
# 316:solution found (8)
# 317
# 317:solution found (9)
# 318
# 318:solution found (7)
# 319
# 319:solution found (15)
# 320
# 320:solution found (7)
# 321
# 321:too long
# 322
# 322:solution found (8)
# 323
# 323:solution found (14)
# 324
# 324:solution found (7)
# 325
# 325:solution found (10)
# 326
# 326:solution found (8)
# 327
# 327:solution found (9)
# 328
# 328:solution found (11)
# 329
# 329:solution not found
# 330
# 330:solution found (9)
# 331
# 331:solution found (9)
# 332
# 332:solution found (29)
# 333
# 333:solution found (10)
# 334
# 334:solution found (9)
# 335
# 335:too long
# 336
# 336:solution found (7)
# 337
# 337:solution found (7)
# 338
# 338:solution found (9)
# 339
# 339:too long
# 340
# 340:solution found (9)
# 341
# 341:solution found (7)
# 342
# 342:solution found (9)
# 343
# 343:solution found (7)
# 344
# 344:solution found (8)
# 345
# 345:solution found (8)
# 346
# 346:solution found (7)
# 347
# 347:solution found (14)
# 348
# 348:solution found (8)
# 349
# 349:solution found (8)
# 350
# 350:solution found (11)
# 351
# 351:solution found (8)
# 352
# 352:solution found (8)
# 353
# 353:solution found (33)
# 354
# 354:too long
# 355
# 355:solution found (54)
# 356
# 356:solution found (13)
# 357
# 357:solution found (10)
# 358
# 358:solution found (9)
# 359
# 359:too long
# 360
# 360:too long
# 361
# 361:too long
# 362
# 362:solution found (9)
# 363
# 363:solution found (8)
# 364
# 364:solution found (10)
# 365
# 365:too long
# 366
# 366:solution found (7)
# 367
# 367:solution found (9)
# 368
# 368:solution found (9)
# 369
# 369:too long
# 370
# 370:too long
# 371
# 371:too long
# 372
# 372:solution found (8)
# 373
# 373:solution found (8)
# 374
# 374:solution found (9)
# 375
# 375:too long
# 376
# 376:solution found (9)
# 377
# 377:solution found (32)
# 378
# 378:solution found (7)
# 379
# 379:solution found (12)
# 380
# 380:too long
# 381
# 381:solution found (8)
# 382
# 382:too long
# 383
# 383:solution found (9)
# 384
# 384:too long
# 385
# 385:solution found (7)
# 386
# 386:solution found (7)
# 387
# 387:solution found (10)
# 388
# 388:solution found (8)
# 389
# 389:solution found (9)
# 390
# 390:too long
# 391
# 391:solution found (9)
# 392
# 392:solution found (9)
# 393
# 393:solution found (11)
# 394
# 394:too long
# 395
# 395:solution found (10)
# 396
# 396:too long
# 397
# 397:too long
# 398
# 398:too long
# 399
# 399:too long
# 400
# 400:solution found (9)
# 401
# 401:solution found (7)
# 402
# 402:too long
# 403
# 403:solution found (9)
# 404
# 404:solution found (7)
# 405
# 405:solution found (8)
# 406
# 406:too long
# 407
# 407:solution found (8)
# 408
# 408:solution found (7)
# 409
# 409:solution found (7)
# 410
# 410:solution found (7)
# 411
# 411:solution found (10)
# 412
# 412:solution found (10)
# 413
# 413:solution found (7)
# 414
# 414:solution found (7)
# 415
# 415:solution found (9)
# 416
# 416:solution found (7)
# 417
# 417:solution found (10)
# 418
# 418:too long
# 419
# 419:solution found (8)
# 420
# 420:solution found (11)
# 421
# 421:too long
# 422
# 422:solution found (7)
# 423
# 423:solution found (7)
# 424
# 424:solution found (9)
# 425
# 425:solution not found
# 426
# 426:too long
# 427
# 427:too long
# 428
# 428:solution found (9)
# 429
# 429:too long
# 430
# 430:solution found (7)
# 431
# 431:solution found (9)
# 432
# 432:too long
# 433
# 433:solution found (55)
# 434
# 434:solution found (7)
# 435
# 435:solution found (8)
# 436
# 436:too long
# 437
# 437:solution found (7)
# 438
# 438:solution found (7)
# 439
# 439:solution found (7)
# 440
# 440:too long
# 441
# 441:solution found (9)
# 442
# 442:too long
# 443
# 443:solution found (8)
# 444
# 444:solution found (8)
# 445
# 445:solution found (7)
# 446
# 446:solution found (7)
# 447
# 447:too long
# 448
# 448:solution found (7)
# 449
# 449:solution found (7)
# 450
# 450:solution found (10)
# 451
# 451:solution not found
# 452
# 452:solution found (9)
# 453
# 453:too long
# 454
# 454:solution found (7)
# 455
# 455:too long
# 456
# 456:solution found (8)
# 457
# cycle
# 458
# 458:solution found (26)
# 459
# 459:solution found (9)
# 460
# 460:solution found (9)
# 461
# 461:solution found (9)
# 462
# 462:too long
# 463
# 463:too long
# 464
# 464:solution found (32)
# 465
# 465:solution not found
# 466
# 466:solution found (9)
# 467
# 467:too long
# 468
# 468:too long
# 469
# 469:too long
# 470
# 470:too long
# 471
# 471:solution found (8)
# 472
# 472:solution found (8)
# 473
# 473:too long
# 474
# 474:solution found (15)
# 475
# 475:solution found (7)
# 476
# 476:solution found (8)
# 477
# 477:solution found (9)
# 478
# 478:solution found (7)
# 479
# 479:solution found (8)
# 480
# 480:solution found (8)
# 481
# 481:too long
# 482
# 482:too long
# 483
# 483:too long
# 484
# 484:solution found (9)
# 485
# 485:solution found (22)
# 486
# 486:solution found (9)
# 487
# 487:solution found (7)
# 488
# 488:solution found (12)
# 489
# 489:too long
# 490
# 490:too long
# 491
# 491:too long
# 492
# cycle
# 493
# 493:too long
# 494
# 494:solution found (9)
# 495
# 495:solution found (9)
# 496
# 496:solution found (7)
# 497
# 497:solution found (13)
# 498
# 498:too long
# 499
# 499:too long
# 500
# 500:solution found (7)
# 501
# cycle
# 502
# 502:solution found (7)
# 503
# 503:too long
# 504
# 504:solution found (8)
# 505
# cycle
# 506
# 506:solution found (9)
# 507
# 507:solution found (15)
# 508
# 508:too long
# 509
# 509:too long
# 510
# 510:too long
# 511
# 511:solution found (9)
# 512
# 512:too long
# 513
# 513:too long
# 514
# 514:solution found (10)
# 515
# 515:too long
# 516
# 516:too long
# 517
# 517:too long
# 518
# 518:solution found (7)
# 519
# 519:too long
# 520
# 520:solution found (8)
# 521
# 521:solution found (10)
# 522
# 522:solution found (21)
# 523
# 523:solution found (7)
# 524
# 524:too long
# 525
# 525:solution found (11)
# 526
# 526:solution found (9)
# 527
# 527:too long
# 528
# 528:too long
# 529
# 529:solution found (14)
# 530
# 530:solution found (14)
# 531
# 531:too long
# 532
# 532:solution found (9)
# 533
# 533:solution found (9)
# 534
# 534:solution found (8)
# 535
# 535:solution found (8)
# 536
# 536:solution found (7)
# 537
# 537:solution found (9)
# 538
# 538:too long
# 539
# 539:solution found (11)
# 540
# 540:solution found (7)
# 541
# 541:solution found (9)
# 542
# 542:solution found (7)
# 543
# cycle
# 544
# 544:solution found (9)
# 545
# 545:too long
# 546
# 546:solution found (8)
# 547
# 547:solution found (8)
# 548
# 548:solution found (7)
# 549
# 549:solution found (7)
# 550
# 550:solution found (9)
# 551
# 551:too long
# 552
# 552:solution found (8)
# 553
# 553:solution found (10)
# 554
# 554:too long
# 555
# 555:solution found (8)
# 556
# 556:solution found (8)
# 557
# 557:solution found (7)
# 558
# 558:solution found (9)
# 559
# 559:too long
# 560
# 560:solution found (9)
# 561
# 561:solution found (7)
# 562
# 562:solution found (10)
# 563
# 563:solution found (9)
# 564
# 564:solution found (7)
# 565
# 565:solution found (8)
# 566
# 566:solution found (8)
# 567
# 567:solution found (16)
# 568
# 568:solution found (7)
# 569
# 569:solution found (7)
# 570
# 570:solution found (7)
# 571
# 571:solution found (9)
# 572
# 572:solution found (7)
# 573
# 573:solution found (8)
# 574
# 574:solution found (7)
# 575
# 575:too long
# 576
# 576:solution found (7)
# 577
# 577:solution found (32)
# 578
# 578:solution found (8)
# 579
# 579:solution found (9)
# 580
# 580:solution found (9)
# 581
# 581:too long
# 582
# 582:solution found (7)
# 583
# 583:solution found (8)
# 584
# 584:solution found (30)
# 585
# 585:solution found (8)
# 586
# 586:solution found (9)
# 587
# 587:solution found (9)
# 588
# 588:solution found (9)
# 589
# 589:too long
# 590
# 590:solution found (32)
# 591
# 591:solution found (14)
# 592
# 592:solution found (9)
# 593
# 593:too long
# 594
# 594:solution found (9)
# 595
# 595:too long
# 596
# 596:solution found (9)
# 597
# 597:solution found (8)
# 598
# 598:solution found (7)
# 599
# 599:solution found (12)
# 600
# 600:too long
# 601
# 601:solution found (10)
# 602
# 602:too long
# 603
# 603:too long
# 604
# 604:solution found (9)
# 605
# 605:too long
# 606
# 606:too long
# 607
# 607:solution found (8)
# 608
# 608:solution found (9)
# 609
# 609:solution found (9)
# 610
# 610:too long
# 611
# cycle
# 612
# 612:too long
# 613
# 613:too long
# 614
# 614:solution found (7)
# 615
# 615:solution found (7)
# 616
# 616:too long
# 617
# 617:solution found (9)
# 618
# 618:too long
# 619
# 619:solution found (10)
# 620
# 620:solution found (10)
# 621
# 621:solution found (7)
# 622
# 622:solution found (11)
# 623
# 623:solution found (7)
# 624
# 624:solution found (33)
# 625
# 625:solution found (9)
# 626
# 626:solution found (9)
# 627
# 627:too long
# 628
# 628:too long
# 629
# 629:solution found (7)
# 630
# 630:solution found (10)
# 631
# 631:too long
# 632
# 632:too long
# 633
# 633:solution found (9)
# 634
# 634:solution found (7)
# 635
# 635:solution found (7)
# 636
# 636:solution found (8)
# 637
# 637:solution found (7)
# 638
# 638:solution found (8)
# 639
# 639:solution found (11)
# 640
# 640:solution found (7)
# 641
# 641:too long
# 642
# 642:solution found (9)
# 643
# 643:solution found (11)
# 644
# 644:solution found (8)
# 645
# 645:too long
# 646
# 646:solution found (9)
# 647
# 647:too long
# 648
# 648:solution found (7)
# 649
# 649:solution found (8)
# 650
# 650:solution found (7)
# 651
# 651:too long
# 652
# 652:solution found (54)
# 653
# 653:solution found (8)
# 654
# cycle
# 655
# 655:solution found (9)
# 656
# 656:too long
# 657
# 657:solution found (8)
# 658
# 658:too long
# 659
# 659:solution found (7)
# 660
# 660:solution found (7)
# 661
# 661:solution found (8)
# 662
# 662:too long
# 663
# 663:solution found (8)
# 664
# 664:solution found (14)
# 665
# 665:solution found (10)
# 666
# 666:solution found (9)
# 667
# 667:too long
# 668
# 668:solution found (7)
# 669
# 669:solution found (10)
# 670
# 670:solution found (8)
# 671
# 671:solution found (9)
# 672
# 672:too long
# 673
# 673:too long
# 674
# 674:solution found (7)
# 675
# 675:too long
# 676
# 676:too long
# 677
# 677:solution found (15)
# 678
# 678:solution found (8)
# 679
# 679:solution found (7)
# 680
# 680:solution found (10)
# 681
# 681:solution found (7)
# 682
# 682:solution found (7)
# 683
# 683:solution found (9)
# 684
# 684:solution found (9)
# 685
# 685:solution found (10)
# 686
# 686:solution found (8)
# 687
# 687:solution found (9)
# 688
# 688:solution found (12)
# 689
# 689:too long
# 690
# 690:solution found (8)
# 691
# 691:solution found (8)
# 692
# 692:too long
# 693
# 693:too long
# 694
# 694:too long
# 695
# 695:solution found (9)
# 696
# 696:solution found (9)
# 697
# 697:too long
# 698
# 698:too long
# 699
# 699:solution found (7)
# 700
# 700:too long
# 701
# 701:solution found (11)
# 702
# 702:solution found (7)
# 703
# 703:solution found (7)
# 704
# 704:solution found (9)
# 705
# 705:solution found (10)
# 706
# 706:solution found (8)
# 707
# 707:solution found (7)
# 708
# 708:too long
# 709
# 709:solution found (11)
# 710
# 710:solution found (9)
# 711
# 711:too long
# 712
# 712:solution found (7)
# 713
# 713:solution found (8)
# 714
# 714:solution found (8)
# 715
# 715:solution found (11)
# 716
# 716:too long
# 717
# 717:solution found (7)
# 718
# 718:solution found (7)
# 719
# 719:too long
# 720
# 720:solution found (10)
# 721
# 721:solution found (7)
# 722
# 722:too long
# 723
# 723:too long
# 724
# 724:solution found (8)
# 725
# 725:solution found (7)
# 726
# 726:solution found (7)
# 727
# 727:solution found (9)
# 728
# 728:solution found (14)
# 729
# 729:solution found (7)
# 730
# 730:solution found (32)
# 731
# 731:solution found (25)
# 732
# 732:too long
# 733
# 733:solution found (8)
# 734
# 734:solution found (7)
# 735
# 735:solution found (7)
# 736
# 736:too long
# 737
# 737:solution found (7)
# 738
# 738:solution found (7)
# 739
# 739:too long
# 740
# 740:too long
# 741
# 741:solution found (8)
# 742
# 742:too long
# 743
# cycle
# 744
# 744:solution found (7)
# 745
# 745:solution found (7)
# 746
# 746:solution found (7)
# 747
# 747:too long
# 748
# 748:solution found (8)
# 749
# 749:solution found (9)
# 750
# 750:solution found (13)
# 751
# 751:solution found (33)
# 752
# 752:too long
# 753
# 753:too long
# 754
# 754:solution found (51)
# 755
# 755:too long
# 756
# 756:too long
# 757
# 757:too long
# 758
# 758:solution found (9)
# 759
# 759:solution found (12)
# 760
# 760:solution found (8)
# 761
# 761:solution found (7)
# 762
# 762:solution found (8)
# 763
# 763:solution found (9)
# 764
# 764:too long
# 765
# 765:solution found (14)
# 766
# 766:solution found (7)
# 767
# 767:solution found (7)
# 768
# 768:too long
# 769
# 769:solution found (10)
# 770
# 770:solution found (8)
# 771
# 771:too long
# 772
# 772:solution found (10)
# 773
# 773:solution not found
# 774
# 774:too long
# 775
# 775:solution found (7)
# 776
# 776:solution found (9)
# 777
# 777:solution found (9)
# 778
# 778:solution found (7)
# 779
# 779:solution found (7)
# 780
# 780:solution found (8)
# 781
# 781:too long
# 782
# 782:too long
# 783
# 783:too long
# 784
# 784:solution found (7)
# 785
# 785:solution found (12)
# 786
# 786:solution found (7)
# 787
# 787:solution found (10)
# 788
# 788:solution found (7)
# 789
# 789:solution found (9)
# 790
# 790:solution found (7)
# 791
# 791:solution found (9)
# 792
# 792:solution found (7)
# 793
# 793:solution found (30)
# 794
# 794:solution found (7)
# 795
# 795:too long
# 796
# 796:solution found (11)
# 797
# 797:solution found (9)
# 798
# 798:too long
# 799
# 799:solution found (8)
# 800
# 800:solution found (8)
# 801
# 801:solution found (9)
# 802
# 802:solution found (9)
# 803
# 803:too long
# 804
# 804:solution found (9)
# 805
# 805:solution found (9)
# 806
# 806:solution found (7)
# 807
# 807:solution found (9)
# 808
# 808:too long
# 809
# 809:solution found (9)
# 810
# 810:too long
# 811
# 811:solution found (8)
# 812
# 812:too long
# 813
# 813:solution found (8)
# 814
# 814:too long
# 815
# 815:solution found (8)
# 816
# 816:solution found (7)
# 817
# 817:too long
# 818
# 818:solution found (7)
# 819
# 819:too long
# 820
# 820:too long
# 821
# 821:too long
# 822
# 822:solution found (8)
# 823
# 823:solution found (13)
# 824
# 824:solution found (25)
# 825
# 825:solution found (8)
# 826
# 826:solution found (7)
# 827
# 827:solution found (9)
# 828
# 828:solution found (7)
# 829
# 829:solution found (9)
# 830
# 830:solution found (9)
# 831
# 831:solution found (7)
# 832
# 832:solution found (8)
# 833
# 833:too long
# 834
# 834:solution found (9)
# 835
# 835:solution found (9)
# 836
# 836:solution found (8)
# 837
# 837:solution not found
# 838
# 838:solution found (12)
# 839
# 839:too long
# 840
# 840:solution found (14)
# 841
# 841:solution found (7)
# 842
# 842:too long
# 843
# 843:too long
# 844
# 844:too long
# 845
# 845:too long
# 846
# 846:too long
# 847
# 847:solution found (7)
# 848
# 848:solution found (8)
# 849
# 849:too long
# 850
# 850:too long
# 851
# 851:too long
# 852
# 852:too long
# 853
# 853:solution found (8)
# 854
# 854:solution found (9)
# 855
# 855:solution found (7)
# 856
# 856:too long
# 857
# 857:solution found (7)
# 858
# 858:solution found (9)
# 859
# 859:solution found (7)
# 860
# 860:solution found (7)
# 861
# 861:solution found (9)
# 862
# 862:solution found (9)
# 863
# 863:solution found (9)
# 864
# 864:solution found (9)
# 865
# 865:too long
# 866
# 866:solution found (15)
# 867
# 867:solution found (12)
# 868
# 868:solution found (9)
# 869
# 869:solution found (8)
# 870
# 870:solution found (8)
# 871
# 871:too long
# 872
# 872:solution found (10)
# 873
# 873:solution found (10)
# 874
# 874:solution found (7)
# 875
# 875:solution found (7)
# 876
# 876:solution found (8)
# 877
# 877:solution found (8)
# 878
# 878:solution found (11)
# 879
# 879:solution found (9)
# 880
# cycle
# 881
# 881:too long
# 882
# 882:solution found (9)
# 883
# 883:solution found (7)
# 884
# 884:solution found (8)
# 885
# 885:solution found (7)
# 886
# 886:solution found (7)
# 887
# 887:solution found (51)
# 888
# 888:too long
# 889
# 889:solution found (7)
# 890
# 890:solution found (8)
# 891
# 891:too long
# 892
# 892:too long
# 893
# 893:solution found (9)
# 894
# 894:too long
# 895
# 895:solution found (9)
# 896
# 896:solution found (11)
# 897
# 897:solution found (9)
# 898
# 898:solution found (9)
# 899
# 899:solution found (7)
# 900
# 900:solution found (8)
# 901
# 901:too long
# 902
# 902:solution found (9)
# 903
# 903:solution found (7)
# 904
# 904:too long
# 905
# 905:too long
# 906
# 906:too long
# 907
# 907:solution found (9)
# 908
# 908:solution found (7)
# 909
# 909:solution found (7)
# 910
# 910:solution found (7)
# 911
# 911:too long
# 912
# 912:solution found (8)
# 913
# 913:solution found (9)
# 914
# 914:solution found (10)
# 915
# 915:solution found (8)
# 916
# 916:solution found (28)
# 917
# 917:solution found (72)
# 918
# 918:solution found (7)
# 919
# 919:solution found (8)
# 920
# 920:solution found (8)
# 921
# 921:too long
# 922
# 922:too long
# 923
# 923:solution found (10)
# 924
# 924:too long
# 925
# 925:too long
# 926
# 926:solution found (9)
# 927
# 927:too long
# 928
# 928:too long
# 929
# 929:solution found (8)
# 930
# 930:solution found (7)
# 931
# 931:solution found (10)
# 932
# 932:solution found (9)
# 933
# 933:too long
# 934
# 934:solution found (7)
# 935
# 935:solution found (95)
# 936
# 936:solution found (7)
# 937
# 937:too long
# 938
# 938:solution found (12)
# 939
# 939:too long
# 940
# 940:too long
# 941
# 941:too long
# 942
# 942:solution found (9)
# 943
# 943:too long
# 944
# 944:solution found (8)
# 945
# 945:solution found (7)
# 946
# 946:solution found (8)
# 947
# 947:too long
# 948
# 948:solution found (7)
# 949
# 949:solution found (7)
# 950
# 950:solution found (7)
# 951
# 951:solution found (7)
# 952
# 952:too long
# 953
# 953:solution found (9)
# 954
# 954:solution found (8)
# 955
# 955:solution found (9)
# 956
# 956:solution found (7)
# 957
# 957:solution found (8)
# 958
# 958:solution found (30)
# 959
# 959:too long
# 960
# 960:solution found (7)
# 961
# 961:too long
# 962
# 962:too long
# 963
# 963:solution found (7)
# 964
# 964:solution found (9)
# 965
# 965:too long
# 966
# 966:solution found (7)
# 967
# 967:solution found (12)
# 968
# 968:solution found (9)
# 969
# 969:too long
# 970
# 970:solution found (7)
# 971
# 971:too long
# 972
# 972:solution found (7)
# 973
# 973:too long
# 974
# 974:solution found (33)
# 975
# 975:solution found (9)
# 976
# 976:too long
# 977
# 977:solution found (8)
# 978
# 978:solution found (8)
# 979
# 979:solution found (9)
# 980
# 980:solution found (7)
# 981
# 981:too long
# 982
# 982:too long
# 983
# 983:solution found (9)
# 984
# 984:solution found (9)
# 985
# 985:solution found (8)
# 986
# 986:solution found (9)
# 987
# 987:solution found (7)
# 988
# 988:too long
# 989
# 989:solution found (7)
# 990
# 990:solution found (7)
# 991
# 991:too long
# 992
# 992:solution found (72)
# 993
# 993:solution found (14)
# 994
# 994:solution found (8)
# 995
# 995:solution found (8)
# 996
# 996:solution found (9)
# 997
# 997:solution found (7)
# 998
# 998:solution found (8)
# 999
# 999:solution found (9)
# 1000
# 1000:solution found (9)
# 1001
# 1001:solution found (29)
# 1002
# 1002:solution found (10)
# 1003
# 1003:too long
# 1004
# 1004:solution found (8)
# 1005
# 1005:solution found (7)
# 1006
# 1006:solution found (7)
# 1007
# 1007:too long
# 1008
# 1008:solution found (7)
# 1009
# 1009:solution found (9)
# 1010
# 1010:solution found (7)
# 1011
# 1011:solution found (8)
# 2199:solution found (9)
# 2200
# 2200:solution found (8)
# 2201
# 2201:solution found (8)
# 2202
# 2202:solution found (53)
# 2203
# 2203:too long
# 2204
# 2204:solution found (14)
# 2205
# 2205:solution found (10)
# 2206
# 2206:solution found (7)
# 2207
# 2207:solution found (33)
# 2208
# 2208:solution found (9)
# 2209
# 2209:solution found (9)
# 2210
# 2210:too long
# 2211
# 2211:solution found (9)
# 2212
# 2212:solution found (8)
# 2213
# 2213:solution found (10)
# 2214
# 2214:solution found (9)
# 2215
# 2215:solution found (8)
# 2216
# 2216:solution found (12)
# 2217
# 2217:solution found (7)
# 2218
# 2218:solution found (53)
# 2219
# 2219:too long
# 2220
# 2220:solution found (15)
# 2221
# 2221:solution found (8)
# 2222
# 2222:solution found (8)
# 2223
# 2223:solution found (8)
# 2224
# 2224:too long
# 2225
# 2225:solution found (8)
# 2226
# 2226:solution found (8)
# 2227
# 2227:solution found (8)
# 2228
# 2228:solution found (9)
# 2229
# 2229:solution found (8)
# 2230
# 2230:too long
# 2231
# 2231:too long
# 2232
# 2232:too long
# 2233
# 2233:solution found (14)
# 2234
# 2234:solution found (7)
# 2235
# 2235:solution found (7)
# 2236
# 2236:too long
# 2237
# 2237:solution found (7)
# 2238
# 2238:solution found (7)
# 2239
# 2239:solution found (29)
# 2240
# 2240:solution found (16)
# 2241
# 2241:solution found (7)
# 2242
# 2242:too long
# 2243
# 2243:solution found (7)
# 2244
# 2244:solution found (8)
# 2245
# 2245:solution found (10)
# 2246
# 2246:solution found (8)
# 2247
# 2247:too long
# 2248
# 2248:too long
# 2249
# 2249:solution found (9)
# 2250
# 2250:solution found (7)
# 2251
# 2251:solution found (7)
# 2252
# 2252:solution found (9)
# 2253
# 2253:too long
# 2254
# 2254:solution found (7)
# 2255
# 2255:too long
# 2256
# 2256:solution found (11)
# 2257
# 2257:too long
# 2258
# 2258:solution found (14)
# 2259
# 2259:solution found (11)
# 2260
# 2260:too long
# 2261
# 2261:solution found (7)
# 2262
# 2262:too long
# 2263
# 2263:too long
# 2264
# 2264:solution found (8)
# 2265
# 2265:solution not found
# 2266
# 2266:too long
# 2267
# 2267:solution found (7)
# 2268
# 2268:solution found (9)
# 2269
# 2269:solution not found
# 2270
# 2270:too long
# 2271
# 2271:too long
# 2272
# 2272:solution found (9)
# 2273
# 2273:too long

# %%
test_data['no rerank'] = results

# %%
test_data.to_csv('results_no_rerank.csv',index=False)

# %%
no_rerank_results = pd.read_csv('results_no_rerank.csv')
results = list(pd_results['0'])
#results = []
no_rerank_results = list(no_rerank_results['no rerank'])
for test_sample in range(0,len(test_data)):
    if no_rerank_results[test_sample]>30:
        try:
            print(test_sample)
            row = test_data.iloc[test_sample]
            rel_id = row['rel id']
            ent_a = row['entity a']
            ent_b = row['entity b']
            query = Term('q'+str(rel_id),Term('ent'+str(ent_a)),Term('ent'+str(ent_b)))
            # Perform incremental grounding.
            # This is a split-up of the engine.execute method.

            # Initialize the engine with options:
            #   - unbuffered: don't buffer results internally in the nodes (mimic depth-first construction of target)
            #   - rc_first: first process 'result' and 'complete' messages (allows stopping on 'evaluation' message)
            #   - label_all: (optional) label all intermediate nodes with their predicate
            engine = problog.engine.DefaultEngine(unbuffered=True, rc_first=True, label_all=True)

            # Target formula
            #   - keep_all: don't collapse non-probabilistic subformula's => only for visualization
            target = problog.formula.LogicFormula(keep_all=True)

            db = engine.prepare(facts_and_rules_Prolog)

            # Start the incremental grounding.
            # The result is a list of 'evaluation' actions.
            actions = list(reversed(engine.ground_step(db, query, gp=target)))

            i = 0
            # Execute until no more 'evaluation' actions can be performed.
            rand_dict={}
            while actions:
                actions = engine.execute_step(actions, steps=1, target=target, name=(False, query, 'query'))

                # HERE YOU CAN DO WHATEVER YOU WANT WITH THE ACTION LIST

                # Below is just generating some output.
                i += 1

                #print('==== STEP %d ====' % i)


                predicates = []
                # Go through the engine's stack and extract predicate evaluation nodes ('EvalDefine')
                for rec in engine.stack:
                    if type(rec).__name__ == 'EvalDefine':  # TODO: we should also include 'EvalOr'?
                        nodes = set(b for a, b, in rec.results.results)  # 'target' nodes associated with this evaluation node
                        predicates.append(problog.logic.Term(rec.call[0], *rec.call[1]))
                #print(predicates)
                actions,rand_dict = rerank_actions(actions,predicates,embeddings_enta,embeddings_entb,embeddings_rel,embeddings_rule,model,neighbors,rand_dict)

                #for act in actions:
                #    print(db.get_node(act[1]))

                if type(engine.stack[0]).__name__=='EvalDefine':
                    trigger_nodes = set(b for a,b, in engine.stack[0].results.results)

                #print ('Active predicates:')
                active_nodes = set()  # These are the nodes in 'target' that are still active.
                # Go through the engine's stack and extract predicate evaluation nodes ('EvalDefine')
                for rec in engine.stack:
                    if type(rec).__name__ == 'EvalDefine':  # TODO: we should also include 'EvalOr'?
                        nodes = set(b for a, b, in rec.results.results)  # 'target' nodes associated with this evaluation node
                        #print ('\t', problog.logic.Term(rec.call[0], *rec.call[1]), list(nodes))
                        active_nodes |= nodes # union
                #print ('Active nodes:', list(active_nodes))

                # Visualize and print the current logic program.
                #%dotstr target.to_dot(nodeprops={n: 'fillcolor="red"' for n in active_nodes})

                if len(list(trigger_nodes))>0:
                    print(str(test_sample)+ ':solution found ('+str(i)+')')
                    results.append(i)
                    pd_results = pd.DataFrame(results)
                    pd_results.to_csv('pd_results.csv',index=False)
                    break

                if i>100:
                    print(str(test_sample)+ ':too long')
                    results.append(0)
                    pd_results = pd.DataFrame(results)
                    pd_results.to_csv('pd_results.csv',index=False)
                    break

                if len(actions)==0:
                    print(str(test_sample)+ ':solution not found')
                    results.append(-1)
                    pd_results = pd.DataFrame(results)
                    pd_results.to_csv('pd_results.csv',index=False)
                    break

        except:
            print('cycle')
            results.append(-2)
            pd_results = pd.DataFrame(results)
            pd_results.to_csv('pd_results.csv',index=False)
            pass
# Out:
# 26
# /home/jasper/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# cycle
# 30
# cycle
# 103
# 103:solution found (15)
# 120
# cycle
# 138
# 138:too long
# 157
# cycle
# 162
# cycle
# 165
# cycle
# 170
# cycle
# 244
# cycle
# 249
# 249:solution found (93)
# 353
# cycle
# 355
# 355:solution found (18)
# 377
# cycle
# 433
# 433:too long
# 464
# cycle
# 577
# cycle
# 590
